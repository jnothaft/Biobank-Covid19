# %%
import pandas as pd
import numpy as np
from random import randrange
from datetime import timedelta
from datetime import datetime
import random
import string
import matplotlib
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower

TOTAL_TEST_COUNT = 10**5
POSITIVE_CASE_FREQ = 0.21
NUM_PATIENTS = 40


START_DATE = datetime.strptime('10/1/2020', '%m/%d/%Y')
# END_DATE = datetime.strptime('10/2/2020', '%m/%d/%Y')

END_DATE = datetime.strptime('4/21/2021', '%m/%d/%Y')


def random_date(start, end):
    delta = end - start
    int_delta = (delta.days * 24 * 60 * 60) + delta.seconds
    random_second = randrange(int_delta)
    d = start + timedelta(seconds=random_second)
    return f"{d.month}/{d.day}/{d.year}"


d = random_date(START_DATE, END_DATE)

sample_results = random.choices(['positive', 'negative'],
                                weights=[POSITIVE_CASE_FREQ, 1 - POSITIVE_CASE_FREQ],
                                k=TOTAL_TEST_COUNT)

sample_type = ['AN'] * TOTAL_TEST_COUNT
test_type = ['RT-PCR'] * TOTAL_TEST_COUNT

test_dates = [random_date(START_DATE, END_DATE) for _ in range(TOTAL_TEST_COUNT)]
collection_site = random.choices(['Kilachand', 'Health Annex', '808 Gallery', 'Agganis Arena Lobby',
                                  'BU Medical Campus'],
                                 k=TOTAL_TEST_COUNT)

users = [''.join(random.choices(string.digits, k=12)) for _ in range(TOTAL_TEST_COUNT)]

user_id_col = random.choices(users, k=TOTAL_TEST_COUNT)

ct_values = []

df = pd.DataFrame([user_id_col, test_dates, sample_results, test_type, sample_type, collection_site,  ct_values]).T
df.columns = ['user_id', 'test_date', 'sample_result', 'test_type', 'sample_type', 'collection_site',  'ct_values']

# %%
df
# Out:
#             user_id   test_date sample_result test_type sample_type  \
# 0      780488767455    3/8/2021      negative    RT-PCR          AN
# 1      096125970412    1/7/2021      negative    RT-PCR          AN
# 2      003193532827   11/9/2020      negative    RT-PCR          AN
# 3      493416375982   1/23/2021      negative    RT-PCR          AN
# 4      999245686804  12/10/2020      negative    RT-PCR          AN
# ...             ...         ...           ...       ...         ...
# 99995  235703110885    1/6/2021      negative    RT-PCR          AN
# 99996  678088865964   12/2/2020      negative    RT-PCR          AN
# 99997  417771982719  11/12/2020      positive    RT-PCR          AN
# 99998  300387430265   3/11/2021      positive    RT-PCR          AN
# 99999  415237487385  11/11/2020      negative    RT-PCR          AN
#
#            collection_site ct_values
# 0      Agganis Arena Lobby      None
# 1             Health Annex      None
# 2             Health Annex      None
# 3      Agganis Arena Lobby      None
# 4                Kilachand      None
# ...                    ...       ...
# 99995          808 Gallery      None
# 99996    BU Medical Campus      None
# 99997  Agganis Arena Lobby      None
# 99998         Health Annex      None
# 99999  Agganis Arena Lobby      None
#
# [100000 rows x 7 columns]

# %%
month_dict = {
    '1': 'Jan',
    '2': 'Feb',
    '3': 'March',
    '4': 'April',
    '5': 'May',
    '6': 'June',
    '7': 'July',
    '8': 'Aug',
    '9': 'Sept',
    '10': 'Oct',
    '11': 'Nov',
    '12': 'Dec',
}

def label_date(date_str):
    month, _, year = date_str.split('/')
    
    new_date_str = f"{month_dict[month]} {year}"
    return new_date_str

def label_date_for_sort(date_str):
    month, _, year = date_str.split('/')
    
    new_date_str = f"{month_dict[month]} {year}"
    return new_date_str

# %%
label_date('2/16/2021')
# Out:
# 'Feb 2021'

# %%
dt = df.copy()

# %%
dt['sample_result'] = dt['sample_result'].map({'positive':1, 'negative':0})
dt['test_date_pretty'] = dt['test_date'].apply(lambda date_str: label_date(date_str))

# %%
agg_map = {'sample_result':'count','test_type':'first', 'user_id':'count', 'test_date':'first' }

# %%
agg_data = dt.groupby('test_date_pretty').agg(agg_map)
agg_data = agg_data.rename({'user_id':'Total Users Tested', 'sample_result': 'Number of Positive Samples'}, axis=1)
agg_data.sort_values('test_date')
# Out:
#                   Number of Positive Samples test_type  Total Users Tested  \
# test_date_pretty
# Jan 2021                               15103    RT-PCR               15103
# Oct 2020                               15498    RT-PCR               15498
# Nov 2020                               14798    RT-PCR               14798
# Dec 2020                               15282    RT-PCR               15282
# Feb 2021                               14049    RT-PCR               14049
# March 2021                             15339    RT-PCR               15339
# April 2021                              9931    RT-PCR                9931
#
#                    test_date
# test_date_pretty
# Jan 2021            1/7/2021
# Oct 2020          10/21/2020
# Nov 2020           11/9/2020
# Dec 2020          12/10/2020
# Feb 2021           2/26/2021
# March 2021          3/8/2021
# April 2021          4/6/2021

# %%
plot_data = agg_data.copy()

# %%
plot_data
# Out:
#             Number of Positive Samples test_type  Total Users Tested
# test_date
# April 2021                        9931    RT-PCR                9931
# Dec 2020                         15282    RT-PCR               15282
# Feb 2021                         14049    RT-PCR               14049
# Jan 2021                         15103    RT-PCR               15103
# March 2021                       15339    RT-PCR               15339
# Nov 2020                         14798    RT-PCR               14798
# Oct 2020                         15498    RT-PCR               15498

# %%
plt.bar(plot_data.index, plot_data['Number of Positive Samples'])
# plt.yticks([])
plt.xlabel('Date')
plt.ylabel('Number of Positive Samples')
# Out:
# Text(0, 0.5, 'Number of Positive Samples')
